# %%
att = [0.003200143827332581, 0.001298551881953274, -0.000827544761970781, -7.51261685260029e-05, 0.0005033450008899096, 0.0005604604370793375, 0.0008553761532519605, 0.0005963599417257191, -0.0002501892688636512, 0.0005552167433700523, -0.0010383458336007411, 0.000869224735016001]
ff = [0.009333776259854978, -0.0004075576791264296, -0.004375692469649232, 0.010935804690053313, -0.017451267165791623, -0.018994378592369483, 0.03859498826543578, -0.03593285898504687, -0.028143361189560165, -0.028780294109906207, 0.026389053011659742, -0.01160085123538732]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(att)

# %%
plt.plot(ff)

# %%
# !conda install -n base ipykernel --update-deps --force-reinstall

# %%
import random
import os
import json
import pandas as pd

# %%
data_name = 'frontal_val_error_random_v1.jsonl'

# %%
data_folder = '/home/data/mimic-cxr-jpg/2.0.0/rred/error_baseline_Mixed_FPI_v0.3'
data_path = os.path.join(data_folder,data_name)
data = [json.loads(l) for l in open(data_path)]

# %%
normal = [json.loads(l) for l in open(os.path.join('/home/data/mimic-cxr-jpg/2.0.0/rred','frontal_val.jsonl'))]

# %%
len(normal)
# Out:
# 1002

# %%
df = pd.DataFrame(data)

# %%
random.seed(0)
data_randomshuffle = random.sample(data_randomshuffle,int(len(data_randomshuffle)/10))

# %%
data_folder = '/home/data/mimic-cxr-jpg/2.0.0/rred/error_baseline_FactualOnly'
data_path = os.path.join(data_folder,data_name)
data_factual = [json.loads(l) for l in open(data_path)]

# %%
data_folder = '/home/data/mimic-cxr-jpg/2.0.0/rred/error_baseline_PerceptualOnly'
data_path = os.path.join(data_folder,data_name)
data_perceptual = [json.loads(l) for l in open(data_path)]

# %%
len(data_randomshuffle)
# Out:
# 1494

# %%
len(data_factual)
# Out:
# 1174

# %%
len(data_perceptual)
# Out:
# 1494

# %%
data_f_p_r = data_randomshuffle+data_factual+data_perceptual

# %%
len(data_f_p_r)
# Out:
# 4162

# %%
folder = "/home/data/mimic-cxr-jpg/2.0.0/rred/error_baseline_Mixed_FPR"

# %%
with open(os.path.join(folder, data_name), encoding= "utf-8",mode="w") as file: 
    for i in data_f_p_r: file.write(json.dumps(i) + "\n")
